# %%
import numpy as np
import matplotlib.pyplot as plt
import ugradio as ugr

# %%
data2e12 = np.loadtxt('output-5-2**12')
data2e11 = np.loadtxt('output-5-2**11')
data2e10 = np.loadtxt('output-5-2**10')
data2e9 = np.loadtxt('output-5-2**9')
data2e8 = np.loadtxt('output-5-2**8')
data2e7 = np.loadtxt('output-5-2**7')
data2e6 = np.loadtxt('output-5-2**6')
data2e5 = np.loadtxt('output-5-2**5')

# %%
t = np.linspace(0, len(data2e12), len(data2e12))
plt.plot(t[-200:-1], data2e12[-200:-1])
ft1 = ugr.dft.dft(data2e12)

# %%
plt.plot(ft1[0], ft1[1])

# %%
t = np.linspace(0, len(data2e7), len(data2e7))
plt.plot(t[-200:-1], data2e7[-200:-1])
ft2 = ugr.dft.dft(data2e7)

# %%
plt.plot(ft2[0], ft2[1])

# %%
t = np.linspace(0, len(data2e6), len(data2e6))
plt.plot(t[-200:-1], data2e6[-200:-1])
ft3 = ugr.dft.dft(data2e6)

# %%
plt.plot(ft3[0], ft3[1])

# %%
t = np.linspace(0, len(data2e5), len(data2e5))
plt.plot(t[-200:-1], data2e5[-200:-1])
ft4 = ugr.dft.dft(data2e5)

# %%
plt.plot(ft4[0], ft4[1])
